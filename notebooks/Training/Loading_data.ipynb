# %%
# Change to the desired directory
import os
from IPython import get_ipython

# Specify the target directory
target_dir = r"E:\Github\Pneumonia\Chest_X-Ray_Pneumonia_PyTorch"

# Use %cd to change directory
get_ipython().run_line_magic('cd', target_dir)
# Out:
# E:\Github\Pneumonia\Chest_X-Ray_Pneumonia_PyTorch
# C:\Users\maraw\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # Importing Libraries needed

# %%
import torch
from torch import nn
from torchvision import models, transforms
from PIL import Image
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pathlib import Path
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# # Importing our DataFrames

# %%
df = pd.read_csv('E:\Github\Pneumonia\Chest_X-Ray_Pneumonia_PyTorch\df_resized_aug.csv')
df.head()
# Out:
#                                         img_path  clas split  \
# 0  data\chest_xray\test\NORMAL\IM-0001-0001.jpeg     0  test
# 1  data\chest_xray\test\NORMAL\IM-0003-0001.jpeg     0  test
# 2  data\chest_xray\test\NORMAL\IM-0005-0001.jpeg     0  test
# 3  data\chest_xray\test\NORMAL\IM-0006-0001.jpeg     0  test
# 4  data\chest_xray\test\NORMAL\IM-0007-0001.jpeg     0  test
#
#                                         resized_path
# 0  data\chest_xray_resized\test\NORMAL\IM-0001-00...
# 1  data\chest_xray_resized\test\NORMAL\IM-0003-00...
# 2  data\chest_xray_resized\test\NORMAL\IM-0005-00...
# 3  data\chest_xray_resized\test\NORMAL\IM-0006-00...
# 4  data\chest_xray_resized\test\NORMAL\IM-0007-00...

# %%
df.shape
# Out:
# (11220, 4)

# %% [markdown]
# # Creating the Objects needed to create the loader of our data

# %%
class XrayDataset(Dataset):
    def __init__(self, df_split, transform):
        self.df_split = df_split
        self.transform = transform

    def __len__(self):
        return len(self.df_split)

    def __getitem__(self, index):
        img_path = self.df_split.iloc[index]['resized_path']
        clas = self.df_split.iloc[index]['clas']
        # Load the image and convert it to grayscale
        image = Image.open(img_path).convert("L")

        img_trans = self.transform(image)

        return img_trans, clas

# %% [markdown]
# # Implementing our data into our loaders

# %% [markdown]
# ### Training DataLoader

# %%
train_dataset = XrayDataset(df_split=df[df['split'] == 'train'], transform = transforms.ToTensor())

# Create a DataLoader for the training dataset
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# #### Visualizing samples from our train loader

# %%
# Get one batch
dataiter = iter(train_loader)
images, labels = next(dataiter)

# Plot 6 images
plt.figure(figsize=(12, 6))
for i in range(6):
    img = images[i]
    img = img.permute(1, 2, 0).numpy() 
    plt.subplot(2, 3, i + 1)
    plt.imshow(img.squeeze(), cmap='gray')
    plt.title(f"Label: {labels[i].item()}")
    plt.axis('on')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Validation DataLoader

# %%
val_dataset = XrayDataset(df_split=df[df['split'] == 'val'], transform=transforms.transforms.ToTensor())
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ### Test DataLoader

# %%
test_dataset = XrayDataset(df_split=df[df['split'] == 'test'], transform=transforms.transforms.ToTensor())
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)
